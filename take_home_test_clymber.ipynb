# %% [markdown]
# # Take home test from Clymber Loong
#
# ## URL of git repo
# - https://github.com/KylinDragon/take-home-work.git
#
# ## URL of launchpad ppa
# - https://launchpad.net/~clymber/+archive/ubuntu/cmatrix
#
# ## The reference guides for the next engineer who is new to the task.
# - Development environment set up reference: **getting_set_up.pdf**
# - The steps of building a debian package: **do_homework.pdf**
# - How to upload source package to ppa, and install from ppa: **ppa.pdf**
# > Note: All the .pdf documents above have a jupyter nobook version
# > that can be executed, they are available in the git repo above.
#
# ## The output of the installation and testing.sh
# > \$ `sudo apt-get install cmatrix`
# > Reading package lists... 0%
# > Reading package lists... 100%
# > Reading package lists... Done
# > Building dependency tree... 0%
# > Building dependency tree... 0%
# > Building dependency tree... 50%
# > Building dependency tree... 50%
# > Building dependency tree... Done
# > Reading state information... 0%
# > Reading state information... 0%
# > Reading state information... Done
# > The following package was automatically installed and is no longer required:
# >   docker-scan-plugin
# > Use 'sudo apt autoremove' to remove it.
# > Suggested packages:
# >   cmatrix-xfont
# > The following NEW packages will be installed:
# >   cmatrix
# > 0 upgraded, 1 newly installed, 0 to remove and 0 not upgraded.
# > Need to get 0 B/18.4 kB of archives.
# > After this operation, 55.3 kB of additional disk space will be used.
# > Selecting previously unselected package cmatrix.
# > (Reading database ... 226799 files and directories currently installed.)
# > Preparing to unpack .../cmatrix_2.0-3ubuntu4ppa1\~ubuntu22.04.1_amd64.deb ...
# > Unpacking cmatrix (2.0-3ubuntu4ppa1\~ubuntu22.04.1) ...
# > Setting up cmatrix (2.0-3ubuntu4ppa1\~ubuntu22.04.1) ...
# > **this is a test from Clymber Loong**
# > Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# > Processing triggers for desktop-file-utils (0.26-1ubuntu3) ...
# > Processing triggers for gnome-menus (3.36.0-1ubuntu3) ...
# > Processing triggers for man-db (2.10.2-1) ...
# >
# > \$ `dpkg -S testing.sh; testing.sh`
# > cmatrix: /usr/bin/testing.sh
# > this is a test from Clymber Loong
# >
# > _Note: The steps and output can be found within **ppa.pdf** and **pda.ipynb**_
